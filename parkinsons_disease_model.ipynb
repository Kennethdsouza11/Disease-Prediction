# %%
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
parkinson_data = pd.read_csv(r'C:\Users\kenneth\OneDrive\Desktop\Disease Prediction\Disease-Prediction\datasets\parkinsons.csv')

# %%
parkinson_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
parkinson_data.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %%
parkinson_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
parkinson_data.shape
# Out:
# (195, 24)

# %%
parkinson_data['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
parkinson_data.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
from pandas.core.dtypes.common import is_numeric_dtype
for column in parkinson_data.columns:
    if is_numeric_dtype(parkinson_data[column]):
        continue
    else:
        parkinson_data[column] = label.fit_transform(parkinson_data[column])

# %%
#seperating the data and labels
X = parkinson_data.drop(columns = ['status', 'name'], axis = 1)
Y = parkinson_data['status']

# %%
print(X)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
parkinson_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
#Data Standardisation
scaler = StandardScaler()
scaler.fit(X)
standardised_data = scaler.transform(X)

# %%
X = standardised_data

# %%
print(X)
# Out:
# [[-0.82929965 -0.43616456 -0.95203729 ...  0.48047686 -0.21053082
#    0.86888575]
#  [-0.77097169 -0.53097409 -0.05772056 ...  1.31118546  0.27507712
#    1.80360503]
#  [-0.90947638 -0.7231683  -0.10987483 ...  1.01768236 -0.10362861
#    1.40266141]
#  ...
#  [ 0.49557839  0.47010361 -0.96839309 ... -0.81807931  0.78033848
#   -0.83241014]
#  [ 1.07876114  2.19004398 -0.95417967 ... -0.22906571 -0.63700298
#   -0.92610456]
#  [ 1.45481664  0.69224632 -0.88348115 ... -0.43085284  0.45480231
#   -0.64505466]]

# %%
#Splitting the data into training and testing data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify = Y, random_state= 1)

# %%
print(X.shape, X_train.shape, X_test.shape, Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22) (195,) (156,) (39,)

# %%
#Training the model
model = svm.SVC(kernel = 'linear')
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
Y_pred= model.predict(X_test)
Y_prediction_accuracy = accuracy_score(Y_test, Y_pred)
print("Model's accuracy score is (related to test data) : ", Y_prediction_accuracy)
# Out:
# Model's accuracy score is (related to test data) :  0.8461538461538461

# %%
# Hyperparameter tuning using Grid Search with cross-validation
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf', 'poly', 'sigmoid']
}
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=2, cv=5)
grid.fit(X_train, Y_train)
best_svm_model = grid.best_estimator_
best_svm_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=   0.0s
# ...

# %%
Y_pred_tuned = best_svm_model.predict(X_test)
Y_pred_tuned_accuracy = accuracy_score(Y_test, Y_pred_tuned)
print("Model's accuracy score is (related to training data) : ", Y_pred_tuned_accuracy)
# Out:
# Model's accuracy score is (related to training data) :  0.9230769230769231

# %%
from sklearn.metrics import r2_score
score_train = r2_score(Y_test, Y_pred_tuned)
print("The model's goodness based on the training data according to r2_score is : ", score_train)
# Out:
# The model's goodness based on the training data according to r2_score is :  0.5965517241379311

# %%
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(Y_test, Y_pred_tuned)
import seaborn as sns
sns.heatmap(cf_matrix, annot = True)
# Out:
# <Axes: >

# %%
#testing with an input data
input_data = (122.40000,148.65000,113.81900,0.00968,0.00008,0.00465,0.00696,0.01394,0.06134,0.62600,0.03134,0.04518,0.04368,0.09403,0.01929,19.08500,0.458359,0.819521,-4.075192,0.335590,2.486855,0.368674
)

#changing the input data to numpyarray
input_data_as_numpy_array = np.asarray(input_data)

#reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

#standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

#predicting the desired output
prediction = model.predict(std_data)

print(prediction)
# Out:
# [[-0.77097169 -0.53097409 -0.05772056  0.71541825  1.03767418  0.45389169
#    1.27680862  0.45268371  1.68173116  1.7684643   1.54791153  2.27650439
#    1.15945391  1.54825419 -0.13784252 -0.63450828 -0.38752443  1.83756192
#    1.47985265  1.31118546  0.27507712  1.80360503]]
# [1]
# c:\Users\kenneth\anaconda3\envs\tf2new\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# SAVING THE MODEL

# %%
import pickle

# %%
filename = 'parkinsons_disease_model.sav'
pickle.dump(best_svm_model, open(filename, 'wb'))
